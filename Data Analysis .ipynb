# %% [markdown]
# # Importing Pandas and Numpy Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading the CSV File

# %%
df=pd.read_csv('c:/users/sam/desktop/Salaries.csv')

# %% [markdown]
# # Showing the  all the data in the Dataset

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 147198  147199           Lilyn Ta
# 147199  147200    James D Dresser
# 147200  147201  Melanie A Schmidt
# 147201  147202    Nicole R Crosby
# 147202  147203   Richard E Olivas
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 147198                           Medical Records Clerk    2243.23
# ...

# %% [markdown]
# # First five rows of the dataset

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# ...

# %% [markdown]
# # Last five data from the dataset

# %%
df.tail()
# Out:
#             Id       EmployeeName                      JobTitle  BasePay  \
# 147198  147199           Lilyn Ta         Medical Records Clerk  2243.23
# 147199  147200    James D Dresser             Recreation Leader  2238.64
# 147200  147201  Melanie A Schmidt                 Social Worker  2172.49
# 147201  147202    Nicole R Crosby              Special Examiner  1889.75
# 147202  147203   Richard E Olivas  Public Svc Aide-Public Works  2189.43
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 147198          0.0      0.00     22.43   2243.23           2265.66  2014
# 147199          0.0      0.00     22.37   2238.64           2261.01  2014
# 147200          0.0     63.29     22.36   2235.78           2258.14  2014
# 147201          0.0      0.00    368.01   1889.75           2257.76  2014
# 147202          0.0     42.03     22.31   2231.46           2253.77  2014
#
#         Notes         Agency Status
# 147198    NaN  San Francisco     PT
# ...

# %% [markdown]
# # Column Names

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %% [markdown]
# # Rows and Columns in a dataset

# %%
df.shape
# Out:
# (147203, 13)

# %% [markdown]
# # Show all the information  in a dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147203 entries, 0 to 147202
# Data columns (total 13 columns):
# Id                  147203 non-null int64
# EmployeeName        147203 non-null object
# JobTitle            147203 non-null object
# BasePay             146598 non-null float64
# OvertimePay         147203 non-null float64
# OtherPay            147203 non-null float64
# Benefits            111044 non-null float64
# TotalPay            147203 non-null float64
# TotalPayBenefits    147203 non-null float64
# Year                147203 non-null int64
# Notes               0 non-null float64
# Agency              147203 non-null object
# Status              36672 non-null object
# dtypes: float64(7), int64(2), object(4)
# memory usage: 14.6+ MB

# %% [markdown]
# # Show the EmployeeName and JobTitle

# %%
df[['EmployeeName','JobTitle']]
# Out:
#              EmployeeName                                        JobTitle
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 147198           Lilyn Ta                           Medical Records Clerk
# 147199    James D Dresser                               Recreation Leader
# 147200  Melanie A Schmidt                                   Social Worker
# 147201    Nicole R Crosby                                Special Examiner
# 147202   Richard E Olivas                    Public Svc Aide-Public Works
#
# [147203 rows x 2 columns]

# %% [markdown]
# # Describe the Dataset

# %%
df.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  147203.000000  146598.000000  147203.000000  147203.000000
# mean    73602.000000   66971.911878    5115.459121    3683.848219
# std     42493.990175   42474.743427   11499.638277    8088.243152
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     36801.500000   35582.635000       0.000000       0.000000
# 50%     73602.000000   65292.775000       0.000000     836.700000
# 75%    110402.500000   95015.212500    4744.620000    4299.505000
# max    147203.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes
# count  111044.000000  147203.000000     147203.000000  147203.000000    0.0
# mean    25333.021440   75495.966630      94606.175204    2012.508081    NaN
# std     15234.877154   50228.232053      62420.953888       1.113317    NaN
# ...

# %% [markdown]
# # Attributes are sorted in  ascending order

# %%
df.sort_index(axis=1).head(5)
# Out:
#           Agency    BasePay  Benefits       EmployeeName  Id  \
# 0  San Francisco  167411.18       NaN     NATHANIEL FORD   1
# 1  San Francisco  155966.02       NaN       GARY JIMENEZ   2
# 2  San Francisco  212739.13       NaN     ALBERT PARDINI   3
# 3  San Francisco   77916.00       NaN  CHRISTOPHER CHONG   4
# 4  San Francisco  134401.60       NaN    PATRICK GARDNER   5
#
#                                          JobTitle  Notes   OtherPay  \
# 0  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY    NaN  400184.25
# 1                 CAPTAIN III (POLICE DEPARTMENT)    NaN  137811.38
# 2                 CAPTAIN III (POLICE DEPARTMENT)    NaN   16452.60
# 3            WIRE ROPE CABLE MAINTENANCE MECHANIC    NaN  198306.90
# 4    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)    NaN  182234.59
#
#    OvertimePay Status   TotalPay  TotalPayBenefits  Year
# 0         0.00    NaN  567595.43         567595.43  2011
# 1    245131.88    NaN  538909.28         538909.28  2011
# ...

# %% [markdown]
# # EmployeeName is Sorted in Ascending, JobTitle is sorted in  Descending

# %%
df.sort_values(['EmployeeName','JobTitle'],ascending=[1,0])
# Out:
#             Id           EmployeeName                   JobTitle   BasePay  \
# 29353    29354       A BERNARD FATOOH  SHERIFF'S PROPERTY KEEPER  19969.37
# 102843  102844      A Bernard  Fatooh  Sheriff's Property Keeper  23908.50
# 66371    66372       A Bernard Fatooh  Sheriff's Property Keeper  18472.35
# 140525  140526       A Bernard Fatooh  Sheriff's Property Keeper  24061.35
# 28469    28470  A ELIZABETH MARCHASIN            PRINCIPAL CLERK  23591.80
# ...        ...                    ...                        ...       ...
# 97363    97364             Zuna T Luu                  Custodian  55026.00
# 134790  134791             Zuna T Luu                  Custodian  54703.00
# 93463    93464            Zuri  Jones   Deputy Probation Officer  71986.90
# 49185    49186             Zuri Jones   Deputy Probation Officer  86588.52
# 132614  132615             Zuri Jones   Deputy Probation Officer  66667.54
#
# ...

# %% [markdown]
# # If the dataset contain null value, it shows True

# %%
df.isnull()
# Out:
#            Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 0       False         False     False    False        False     False
# 1       False         False     False    False        False     False
# 2       False         False     False    False        False     False
# 3       False         False     False    False        False     False
# 4       False         False     False    False        False     False
# ...       ...           ...       ...      ...          ...       ...
# 147198  False         False     False    False        False     False
# 147199  False         False     False    False        False     False
# 147200  False         False     False    False        False     False
# 147201  False         False     False    False        False     False
# 147202  False         False     False    False        False     False
#
#         Benefits  TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# ...

# %% [markdown]
# # Filling FILLNA instead of NaN

# %%
df.fillna(value="FILLNA")
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 147198  147199           Lilyn Ta
# 147199  147200    James D Dresser
# 147200  147201  Melanie A Schmidt
# 147201  147202    Nicole R Crosby
# 147202  147203   Richard E Olivas
#
#                                               JobTitle  BasePay  OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY   167411         0.00
# 1                      CAPTAIN III (POLICE DEPARTMENT)   155966    245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)   212739    106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916     56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134402      9737.00
# ...                                                ...      ...          ...
# ...

# %% [markdown]
# # Finding Average  of Basepay

# %%
df['BasePay'].mean()
# Out:
# 66971.91187808

# %% [markdown]
# # Finding median of Basepay

# %%
df['BasePay'].median()
# Out:
# 65292.774999999994

# %% [markdown]
# # Finding Standard Deviation of Basepay

# %%
df['BasePay'].std()
# Out:
# 42474.743426650144

# %% [markdown]
# # Finding the JobTitle and their counts

# %%
df['JobTitle'].value_counts()
# Out:
# Transit Operator                                 7001
# Special Nurse                                    4226
# Registered Nurse                                 3726
# Police Officer 3                                 2420
# Custodian                                        2406
#                                                  ...
# EMERGENCY PROTECTIVE ORDERS COMMISSIONER            1
# Asst Chf Prob Ofc, Juv Prob                         1
# SPECIAL ASSISTANT XIV                               1
# ASST. CHIEF, BUREAU OF CLAIMS INVEST. & ADMIN       1
# ROOFER SUPERVISOR I                                 1
# Name: JobTitle, Length: 2157, dtype: int64

# %% [markdown]
# # Top 5 most JobTitle

# %%
df['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator    7001
# Special Nurse       4226
# Registered Nurse    3726
# Police Officer 3    2420
# Custodian           2406
# Name: JobTitle, dtype: int64

# %% [markdown]
# # Least 5 JobTitle

# %%
df['JobTitle'].value_counts().tail(5)
# Out:
# EMERGENCY PROTECTIVE ORDERS COMMISSIONER         1
# Asst Chf Prob Ofc, Juv Prob                      1
# SPECIAL ASSISTANT XIV                            1
# ASST. CHIEF, BUREAU OF CLAIMS INVEST. & ADMIN    1
# ROOFER SUPERVISOR I                              1
# Name: JobTitle, dtype: int64

# %% [markdown]
# # Average OtherPay of all the employee in 2011-2014

# %%
df.groupby('Year').mean()['OtherPay']
# Out:
# Year
# 2011    3617.081926
# 2012    3653.437583
# 2013    3819.969007
# 2014    3640.581461
# Name: OtherPay, dtype: float64

# %% [markdown]
# # TotalPay of all the Employee

# %%
df['TotalPay']
# Out:
# 0         567595.43
# 1         538909.28
# 2         335279.91
# 3         332343.61
# 4         326373.19
#             ...
# 147198      2243.23
# 147199      2238.64
# 147200      2235.78
# 147201      1889.75
# 147202      2231.46
# Name: TotalPay, Length: 147203, dtype: float64

# %% [markdown]
# # Maximum TotalPay

# %%
df['TotalPay'].max()
# Out:
# 567595.43

# %% [markdown]
# # Minimum TotalPay

# %%
df['TotalPay'].min()
# Out:
# 0.0

# %% [markdown]
# # Find the person who is having  the maximum TotalPay

# %%
df[df['TotalPay']==df['TotalPay'].max()][['EmployeeName','JobTitle']]
# Out:
#      EmployeeName                                        JobTitle
# 0  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY

# %% [markdown]
# # Find the person who is having minimum TotalPay

# %%
df[df['TotalPay']==df['TotalPay'].min()][['EmployeeName','JobTitle','TotalPay']]
# Out:
#               EmployeeName                                    JobTitle  \
# 36156       PAULETTE ADAMS  STATIONARY ENGINEER, WATER TREATMENT PLANT
# 36157        KAUKAB MOHSIN                            TRANSIT OPERATOR
# 36158   JOSEPHINE MCCREARY                                  MANAGER IV
# 70877        Roland Baylon                       Deputy Court Clerk II
# 70927     Felecia Phillips                            Registered Nurse
# ...                    ...                                         ...
# 145956    Kenneth C Farris                                 Firefighter
# 145957    Jordan L Cabrera                          Physical Therapist
# 145958       Gigi V Miller              Community Police Services Aide
# 145959  Allyson S Nakayama                   Psychiatric Social Worker
# 145960   Heriberto Cardoza                         Arborist Technician
#
#         TotalPay
# 36156        0.0
# 36157        0.0
# 36158        0.0
# 70877        0.0
# 70927        0.0
# ...

# %% [markdown]
# # Find the nunique value of TotalPayBenefits

# %%
df['TotalPayBenefits'].nunique()
# Out:
# 140876

# %% [markdown]
# # Find the EmployeeName of 'PAULETTE ADAMS'

# %%
df[df['EmployeeName']=='PAULETTE ADAMS']
# Out:
#           Id    EmployeeName                                    JobTitle  \
# 36156  36157  PAULETTE ADAMS  STATIONARY ENGINEER, WATER TREATMENT PLANT
#
#        BasePay  OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  \
# 36156      0.0          0.0       0.0       NaN       0.0               0.0
#
#        Year  Notes         Agency Status
# 36156  2011    NaN  San Francisco    NaN

# %% [markdown]
# # Find the EmployeeName of 'ALBERT PARDINI' or the JobTitle is 'Police Officer 3'

# %%
df[(df['EmployeeName']=='ALBERT PARDINI') | (df['JobTitle']=='Police Officer 3')]
# Out:
#             Id        EmployeeName                         JobTitle  \
# 2            3      ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)
# 36314    36315           Eric Neff                 Police Officer 3
# 36317    36318      Timothy Gibson                 Police Officer 3
# 36349    36350  Constantine Zachos                 Police Officer 3
# 36478    36479         David Kucia                 Police Officer 3
# ...        ...                 ...                              ...
# 144126  144127     Anton G Collins                 Police Officer 3
# 145165  145166     Judith M Peters                 Police Officer 3
# 145292  145293        Lisa M Curry                 Police Officer 3
# 145511  145512     Salina A Tuvera                 Police Officer 3
# 145633  145634        Rodney C Lee                 Police Officer 3
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# 2       212739.13    106088.18   16452.60       NaN  335279.91
# ...

# %% [markdown]
# # To find the EmployeeName of 'David  kucia' and their JobTitle is 'Police Officer 3'

# %%
 df[(df['EmployeeName']=='David Kucia') & (df['JobTitle']=='Police Officer 3')]
# Out:
#           Id EmployeeName          JobTitle   BasePay  OvertimePay   OtherPay  \
# 36478  36479  David Kucia  Police Officer 3  99304.33     18181.32  111506.56
#
#        Benefits   TotalPay  TotalPayBenefits  Year  Notes         Agency  \
# 36478  27819.75  228992.21         256811.96  2012    NaN  San Francisco
#
#       Status
# 36478    NaN

# %% [markdown]
# # Number of person in 2013 JobTitle

# %%
sum(df[df['Year']==2013]['JobTitle'].value_counts()==1)
# Out:
# 202

# %% [markdown]
# # Deleting the status attribute temporarly

# %%
df.drop('Status',axis=1)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 147198  147199           Lilyn Ta
# 147199  147200    James D Dresser
# 147200  147201  Melanie A Schmidt
# 147201  147202    Nicole R Crosby
# 147202  147203   Richard E Olivas
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 147198                           Medical Records Clerk    2243.23
# ...

# %% [markdown]
# # Deleting the status attribute permanently

# %%
df.drop('Status',axis=1,inplace=True)

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 147198  147199           Lilyn Ta
# 147199  147200    James D Dresser
# 147200  147201  Melanie A Schmidt
# 147201  147202    Nicole R Crosby
# 147202  147203   Richard E Olivas
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 147198                           Medical Records Clerk    2243.23
# ...

# %% [markdown]
# # Deleting the particular row

# %%
df.drop(0)
# Out:
#             Id       EmployeeName  \
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# 5            6     DAVID SULLIVAN
# ...        ...                ...
# 147198  147199           Lilyn Ta
# 147199  147200    James D Dresser
# 147200  147201  Melanie A Schmidt
# 147201  147202    Nicole R Crosby
# 147202  147203   Richard E Olivas
#
#                                             JobTitle    BasePay  OvertimePay  \
# 1                    CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                    CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3               WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4       DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# 5                          ASSISTANT DEPUTY CHIEF II  118602.00      8601.00
# ...                                              ...        ...          ...
# ...
